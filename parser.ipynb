# %%
# !pip3 install beautifulsoup4 requests pydantic

# %%
import requests 
from bs4 import BeautifulSoup
import bs4
from dataclasses import dataclass, asdict
import json
import re

# %%
resp = requests.get("https://en.wikipedia.org/wiki/List_of_TCP_and_UDP_port_numbers", headers={"User-Agent": "curl/8.7.1"})
resp.raise_for_status()

soup = BeautifulSoup(resp.text)
soup.title
# Out:
# <title>List of TCP and UDP port numbers - Wikipedia</title>

# %%
@dataclass
class Port:
    start: int
    end: int
    
    category: str 
    description: str 

    types: dict[str, str]

# %%
def purify(v: str) -> str:
    return re.sub(r'\[.*?\d+\]', '', v).strip()

purify("De-assigned on 2025-02-13, previously compressnet[2]\n")
# Out:
# 'De-assigned on 2025-02-13, previously compressnet'

# %%
def port_number_to_range(v: str) -> tuple[int, int]:
    parts = v.split("–")
    if len(parts) == 1:
        port = int(parts[0])
        return port, port

    return int(parts[0]), int(parts[1])

port_number_to_range("10"), port_number_to_range("50–70")
# Out:
# ((10, 10), (50, 70))

# %%
ports: list[Port] = []

table_to_category = {"Registered ports": "Registered", "Well-known ports": "WellKnown", "Dynamic, private or ephemeral ports": "Other"}

for table in soup.select("table.sortable"):
    tbody = table.select_one("tbody")

    category = table_to_category[purify(table.select_one("caption").text)]
    
    prev_colspan = 1
    port_number = (1, 1)
    
    for tr in list(tbody.children)[1:]:
        if isinstance(tr, bs4.element.NavigableString):
            continue
            
        children = []
        for child in tr.children:
            if not isinstance(child, bs4.element.Tag):
                continue

            children.append(child)

        rowspaned = True
        prev_colspan -= 1
        if prev_colspan <= 0:
            rowspaned = False
            port_number = port_number_to_range(purify(children[0].text))
            prev_colspan = int(children[0].attrs.get("rowspan", 1))

        types = {}
        port_types = iter(["tcp", "udp", "sctp", "dccp"])

        skip = 0 if rowspaned else 1
        for child in children[skip:-1]:
            text = purify(child.text)
            colspan = int(child.attrs.get("colspan", 1))

            for _ in range(colspan):
                port_type = next(port_types)
                
                if text != "":
                    types[port_type] = text    

        start, end = port_number
        port = Port(start=start, end=end, description = purify(children[-1].text), category=category, types=types)
        ports.append(port)

print(len(ports))
for port in ports[:500]:
    print(port)
# Out:
# 1522
# Port(start=0, end=0, category='WellKnown', description='In programming APIs (not in communication between hosts), requests a system-allocated (dynamic) port', types={'tcp': 'Reserved', 'udp': 'Reserved'})
# Port(start=1, end=1, category='WellKnown', description='TCP Port Service Multiplexer (TCPMUX). Historic. Both TCP and UDP have been assigned to TCPMUX by IANA, but by design only TCP is specified.', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=2, end=2, category='WellKnown', description='De-assigned on 2025-02-13, previously compressnet', types={'tcp': 'Reserved', 'udp': 'Reserved'})
# Port(start=3, end=3, category='WellKnown', description='De-assigned on 2025-02-13, previously compressnet', types={'tcp': 'Reserved', 'udp': 'Reserved'})
# Port(start=5, end=5, category='WellKnown', description='Remote Job Entry was historically using socket 5 in its old socket form, while MIB PIM has identified it as TCP/5 and IANA has assigned both TCP and UDP 5 to it.', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=7, end=7, category='WellKnown', description='Echo Protocol', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=9, end=9, category='WellKnown', description='Discard Protocol', types={'tcp': 'Yes', 'udp': 'Yes', 'sctp': 'Yes', 'dccp': 'Assigned'})
# Port(start=9, end=9, category='WellKnown', description='Wake-on-LAN', types={'tcp': 'No', 'udp': 'Unofficial'})
# Port(start=11, end=11, category='WellKnown', description='Active Users (systat service)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=13, end=13, category='WellKnown', description='Daytime Protocol', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=15, end=15, category='WellKnown', description='Previously netstat service', types={'tcp': 'Unofficial', 'udp': 'No'})
# Port(start=17, end=17, category='WellKnown', description='Quote of the Day (QOTD)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=18, end=18, category='WellKnown', description='Message Send Protocol', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=19, end=19, category='WellKnown', description='Character Generator Protocol (CHARGEN)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=20, end=20, category='WellKnown', description='File Transfer Protocol (FTP) data transfer', types={'tcp': 'Yes', 'udp': 'Assigned', 'sctp': 'Yes'})
# Port(start=21, end=21, category='WellKnown', description='File Transfer Protocol (FTP) control (command)', types={'tcp': 'Yes', 'udp': 'Assigned', 'sctp': 'Yes'})
# Port(start=22, end=22, category='WellKnown', description='Secure Shell (SSH), secure logins, file transfers (scp, sftp) and port forwarding', types={'tcp': 'Yes', 'udp': 'Assigned', 'sctp': 'Yes'})
# Port(start=23, end=23, category='WellKnown', description='Telnet protocol—unencrypted text communications', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=24, end=24, category='WellKnown', description='"any private mail system", often used for LMTP.', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=25, end=25, category='WellKnown', description='Simple Mail Transfer Protocol (SMTP), used for email routing between mail servers', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=27, end=27, category='WellKnown', description='nsw-fe (NSW User System FE)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=28, end=28, category='WellKnown', description="Palo Alto Networks' Panorama High Availability (HA) sync encrypted port.", types={'tcp': 'Unofficial'})
# Port(start=29, end=29, category='WellKnown', description='msg-icp (MSG ICP)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=31, end=31, category='WellKnown', description='msg-auth (MSG Authentication)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=33, end=33, category='WellKnown', description='dsp (Display Support Protocol)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=37, end=37, category='WellKnown', description='Time Protocol', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=38, end=38, category='WellKnown', description='rap (Route Access Protocol)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=39, end=39, category='WellKnown', description='rlp (Resource Location Protocol)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=41, end=41, category='WellKnown', description='graphics (Graphics)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=42, end=42, category='WellKnown', description='Host Name Server Protocol', types={'tcp': 'Assigned', 'udp': 'Yes'})
# Port(start=43, end=43, category='WellKnown', description='WHOIS protocol', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=44, end=44, category='WellKnown', description='mpm-flags\t(MPM FLAGS Protocol)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=45, end=45, category='WellKnown', description='mpm (Message Processing Module', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=46, end=46, category='WellKnown', description='mpm-snd (MPM', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=47, end=47, category='WellKnown', description='', types={'tcp': 'Reserved', 'udp': 'Reserved'})
# Port(start=48, end=48, category='WellKnown', description='auditd (Digital Audit Daemon)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=49, end=49, category='WellKnown', description='TACACS Login Host protocol. TACACS+, still in draft which is an improved but distinct version of TACACS, only uses TCP 49.', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=50, end=50, category='WellKnown', description='re-mail-ck (Remote Mail Checking Protocol)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=51, end=51, category='WellKnown', description='Historically used for Interface Message Processor logical address management, entry has been removed by IANA on 2013-05-25', types={'tcp': 'Reserved', 'udp': 'Reserved'})
# Port(start=52, end=52, category='WellKnown', description='Xerox Network Systems (XNS) Time Protocol. Despite this port being assigned by IANA, the service is meant to work on SPP (ancestor of IPX/SPX), instead of TCP/IP.', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=53, end=53, category='WellKnown', description='Domain Name System (DNS)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=54, end=54, category='WellKnown', description='Xerox Network Systems (XNS) Clearinghouse (Name Server). Despite this port being assigned by IANA, the service is meant to work on SPP (ancestor of IPX/SPX), instead of TCP/IP.', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=55, end=55, category='WellKnown', description='isi-gl (ISI Graphics Language)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=56, end=56, category='WellKnown', description='Xerox Network Systems (XNS) Authentication Protocol. Despite this port being assigned by IANA, the service is meant to work on SPP (ancestor of IPX/SPX), instead of TCP/IP.', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=58, end=58, category='WellKnown', description='Xerox Network Systems (XNS) Mail. Despite this port being assigned by IANA, the service is meant to work on SPP (ancestor of IPX/SPX), instead of TCP/IP.', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=61, end=61, category='WellKnown', description="Historically assigned to the NIFTP-Based Mail protocol, but was never documented in the related IEN. The port number entry was removed from IANA's registry on 2017-05-18.", types={'tcp': 'Reserved', 'udp': 'Reserved'})
# Port(start=62, end=62, category='WellKnown', description='acas (ACA Services)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=63, end=63, category='WellKnown', description='whoispp (whois++)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=64, end=64, category='WellKnown', description='covia (Communications Integrator (CI))', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=65, end=65, category='WellKnown', description='tacacs-ds (TACACS-Database Service)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=66, end=66, category='WellKnown', description='sql-net (Oracle SQL*NET)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=67, end=67, category='WellKnown', description='Bootstrap Protocol (BOOTP) server; also used by Dynamic Host Configuration Protocol (DHCP)', types={'tcp': 'Assigned', 'udp': 'Yes'})
# Port(start=68, end=68, category='WellKnown', description='Bootstrap Protocol (BOOTP) client; also used by Dynamic Host Configuration Protocol (DHCP)', types={'tcp': 'Assigned', 'udp': 'Yes'})
# Port(start=69, end=69, category='WellKnown', description='Trivial File Transfer Protocol (TFTP)', types={'tcp': 'Assigned', 'udp': 'Yes'})
# Port(start=70, end=70, category='WellKnown', description='Gopher protocol', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=71, end=74, category='WellKnown', description='NETRJS protocol', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=76, end=76, category='WellKnown', description='deos (Distributed External Object Store)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=78, end=78, category='WellKnown', description='vettcp (vettcp)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=79, end=79, category='WellKnown', description='Finger protocol', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=80, end=80, category='WellKnown', description='Hypertext Transfer Protocol (HTTP) uses TCP in versions 1.x and 2. HTTP/3 uses QUIC, a transport protocol on top of UDP.', types={'tcp': 'Yes', 'udp': 'Yes', 'sctp': 'Yes'})
# Port(start=81, end=81, category='WellKnown', description='TorPark onion routing', types={'tcp': 'Unofficial'})
# Port(start=82, end=82, category='WellKnown', description='xfer (XFER Utility)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=82, end=82, category='WellKnown', description='TorPark control', types={'udp': 'Unofficial'})
# Port(start=83, end=83, category='WellKnown', description='mit-ml-dev (MIT ML Device)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=84, end=84, category='WellKnown', description='ctf (Common Trace Facility)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=85, end=85, category='WellKnown', description='mit-ml-dev (MIT ML Device)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=86, end=86, category='WellKnown', description='mfcobol (Micro Focus Cobol)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=88, end=88, category='WellKnown', description='Kerberos authentication system', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=89, end=89, category='WellKnown', description='su-mit-tg\t(SU/MIT Telnet Gateway)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=90, end=90, category='WellKnown', description='dnsix\t(DNSIX Security Attribute Token Map)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=90, end=90, category='WellKnown', description='PointCast (dotcom)', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=91, end=91, category='WellKnown', description='mit-dov (MIT Dover Spooler)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=92, end=92, category='WellKnown', description='npp (Network Printing Protocol)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=93, end=93, category='WellKnown', description='dcp (Device Control Protocol)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=94, end=94, category='WellKnown', description='objcall (Tivoli Object Dispatcher)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=95, end=95, category='WellKnown', description='SUPDUP, terminal-independent remote login', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=96, end=96, category='WellKnown', description='dixie (DIXIE Protocol Specification)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=97, end=97, category='WellKnown', description='swift-rvf (Swift Remote Virtual File Protocol)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=98, end=98, category='WellKnown', description='tacnews (TAC News)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=99, end=99, category='WellKnown', description='metagram (Metagram Relay)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=101, end=101, category='WellKnown', description='NIC host name', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=102, end=102, category='WellKnown', description='ISO Transport Service Access Point (TSAP) Class 0 protocol;', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=104, end=104, category='WellKnown', description='Digital Imaging and Communications in Medicine (DICOM; also port 11112)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=105, end=105, category='WellKnown', description='CCSO Nameserver', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=106, end=106, category='WellKnown', description='macOS Server, (macOS) password server', types={'tcp': 'Unofficial', 'udp': 'No'})
# Port(start=107, end=107, category='WellKnown', description='Remote User Telnet Service (RTelnet)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=108, end=108, category='WellKnown', description='IBM Systems Network Architecture (SNA) gateway access server', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=109, end=109, category='WellKnown', description='Post Office Protocol, version 2 (POP2)', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=110, end=110, category='WellKnown', description='Post Office Protocol, version 3 (POP3)', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=111, end=111, category='WellKnown', description='Open Network Computing Remote Procedure Call (ONC RPC, sometimes referred to as Sun RPC)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=112, end=112, category='WellKnown', description='McIDAS Data Transmission Protocol', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=113, end=113, category='WellKnown', description='Ident, authentication service/identification protocol, used by IRC servers to identify users', types={'tcp': 'Yes', 'udp': 'No'})
# Port(start=113, end=113, category='WellKnown', description="Authentication Service (auth), the predecessor to identification protocol. Used to determine a user's identity of a particular TCP connection.", types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=115, end=115, category='WellKnown', description='Simple File Transfer Protocol', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=117, end=117, category='WellKnown', description='UUCP Mapping Project (path service)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=118, end=118, category='WellKnown', description='Structured Query Language (SQL) Services[jargon]', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=119, end=119, category='WellKnown', description='Network News Transfer Protocol (NNTP), retrieval of newsgroup messages', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=123, end=123, category='WellKnown', description='Network Time Protocol (NTP), used for time synchronization', types={'tcp': 'Assigned', 'udp': 'Yes'})
# Port(start=126, end=126, category='WellKnown', description="Formerly Unisys Unitary Login, renamed by Unisys to NXEdit. Used by Unisys Programmer's Workbench for Clearpath MCP, an IDE for Unisys MCP software development", types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=135, end=135, category='WellKnown', description='DCE endpoint resolution', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=135, end=135, category='WellKnown', description='Microsoft EPMAP (End Point Mapper), also known as DCE/RPC Locator service, used to remotely manage services including DHCP server, DNS server and WINS. Also used by DCOM', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=137, end=137, category='WellKnown', description='NetBIOS Name Service, used for name registration and resolution', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=138, end=138, category='WellKnown', description='NetBIOS Datagram Service', types={'tcp': 'Assigned', 'udp': 'Yes'})
# Port(start=139, end=139, category='WellKnown', description='NetBIOS Session Service', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=143, end=143, category='WellKnown', description='Internet Message Access Protocol (IMAP), management of electronic mail messages on a server', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=151, end=151, category='WellKnown', description='HEMS', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=152, end=152, category='WellKnown', description='Background File Transfer Program (BFTP)[importance?]', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=153, end=153, category='WellKnown', description='Simple Gateway Monitoring Protocol (SGMP), a protocol for remote inspection and alteration of gateway management information', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=156, end=156, category='WellKnown', description='Structured Query Language (SQL) Service[jargon]', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=158, end=158, category='WellKnown', description='Distributed Mail System Protocol (DMSP, sometimes referred to as Pcmail)[importance?]', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=161, end=161, category='WellKnown', description='Simple Network Management Protocol (SNMP)', types={'tcp': 'Assigned', 'udp': 'Yes'})
# Port(start=162, end=162, category='WellKnown', description='Simple Network Management Protocol Trap (SNMPTRAP)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=165, end=165, category='WellKnown', description='Xerox', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=169, end=169, category='WellKnown', description='SEND', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=170, end=170, category='WellKnown', description='Network PostScript print server', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=175, end=175, category='WellKnown', description='VMNET service using NJE', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=177, end=177, category='WellKnown', description='X Display Manager Control Protocol (XDMCP), used for remote logins to an X Display Manager server[self-published source]', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=179, end=179, category='WellKnown', description='Border Gateway Protocol (BGP), used to exchange routing and reachability information among autonomous systems (AS) on the Internet', types={'tcp': 'Yes', 'udp': 'Assigned', 'sctp': 'Yes'})
# Port(start=180, end=180, category='WellKnown', description='ris', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=194, end=194, category='WellKnown', description='Internet Relay Chat (IRC)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=199, end=199, category='WellKnown', description='SNMP Unix Multiplexer (SMUX)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=201, end=201, category='WellKnown', description='AppleTalk Routing Maintenance', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=209, end=209, category='WellKnown', description='Quick Mail Transfer Protocol[self-published source]', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=210, end=210, category='WellKnown', description='ANSI Z39.50', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=213, end=213, category='WellKnown', description='Internetwork Packet Exchange (IPX)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=218, end=218, category='WellKnown', description='Message posting protocol (MPP)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=220, end=220, category='WellKnown', description='Internet Message Access Protocol (IMAP), version 3', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=225, end=241, category='WellKnown', description='', types={'tcp': 'Reserved', 'udp': 'Reserved'})
# Port(start=249, end=255, category='WellKnown', description='', types={'tcp': 'Reserved', 'udp': 'Reserved'})
# Port(start=259, end=259, category='WellKnown', description='Efficient Short Remote Operations (ESRO)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=262, end=262, category='WellKnown', description='Arcisdms', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=264, end=264, category='WellKnown', description='Border Gateway Multicast Protocol (BGMP)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=280, end=280, category='WellKnown', description='http-mgmt', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=300, end=300, category='WellKnown', description='ThinLinc Web Access, Spartan protocol', types={'tcp': 'Unofficial'})
# Port(start=308, end=308, category='WellKnown', description='Novastor Online Backup', types={'tcp': 'Yes'})
# Port(start=311, end=311, category='WellKnown', description='macOS Server Admin (officially AppleShare IP Web administration)', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=312, end=312, category='WellKnown', description='macOS Xsan administration', types={'tcp': 'Unofficial', 'udp': 'No'})
# Port(start=318, end=318, category='WellKnown', description='PKIX Time Stamp Protocol (TSP)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=319, end=319, category='WellKnown', description='Precision Time Protocol (PTP) event messages', types={'udp': 'Yes'})
# Port(start=320, end=320, category='WellKnown', description='Precision Time Protocol (PTP) general messages', types={'udp': 'Yes'})
# Port(start=323, end=323, category='WellKnown', description='Resource Public Key Infrastructure', types={'tcp': 'Yes'})
# Port(start=350, end=350, category='WellKnown', description='Mapping of Airline Traffic over Internet Protocol (MATIP) type A', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=351, end=351, category='WellKnown', description='MATIP type B', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=356, end=356, category='WellKnown', description='cloanto-net-1 (used by Cloanto Amiga Explorer and VMs)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=366, end=366, category='WellKnown', description='On-Demand Mail Relay (ODMR)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=369, end=369, category='WellKnown', description='Rpc2portmap', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=370, end=370, category='WellKnown', description='codaauth2, Coda authentication server', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=370, end=370, category='WellKnown', description="securecast1, outgoing packets to NAI's SecureCast serversAs of 2000[update]", types={'udp': 'Yes'})
# Port(start=371, end=371, category='WellKnown', description='ClearCase albd', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=376, end=376, category='WellKnown', description='Amiga Envoy Network Inquiry Protocol', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=383, end=383, category='WellKnown', description='HP data alarm manager', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=384, end=384, category='WellKnown', description='A Remote Network Server System', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=387, end=387, category='WellKnown', description='AURP (AppleTalk Update-based Routing Protocol)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=388, end=388, category='WellKnown', description='Unidata LDM near real-time data distribution protocol[self-published source]', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=389, end=389, category='WellKnown', description='Lightweight Directory Access Protocol (LDAP)', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=399, end=399, category='WellKnown', description='Digital Equipment Corporation DECnet+ (Phase V) over TCP/IP (RFC1859)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=401, end=401, category='WellKnown', description='Uninterruptible power supply (UPS)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=427, end=427, category='WellKnown', description='Service Location Protocol (SLP)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=433, end=433, category='WellKnown', description='NNTP, part of Network News Transfer Protocol', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=434, end=434, category='WellKnown', description='Mobile IP Agent (RFC 5944)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=443, end=443, category='WellKnown', description='Hypertext Transfer Protocol Secure (HTTPS) uses TCP in versions 1.x and 2. HTTP/3 uses QUIC, a transport protocol on top of UDP.', types={'tcp': 'Yes', 'udp': 'Yes', 'sctp': 'Yes'})
# Port(start=444, end=444, category='WellKnown', description='Simple Network Paging Protocol (SNPP), RFC 1568', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=445, end=445, category='WellKnown', description='Microsoft-DS (Directory Services) Active Directory, Windows shares', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=445, end=445, category='WellKnown', description='Microsoft-DS (Directory Services) SMB file sharing', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=464, end=464, category='WellKnown', description='Kpasswd: Kerberos Change/Set password', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=465, end=465, category='WellKnown', description='Message Submission over TLS protocol', types={'tcp': 'Yes', 'udp': 'No'})
# Port(start=465, end=465, category='WellKnown', description='URL Rendezvous Directory for Cisco SSM', types={'tcp': 'Yes', 'udp': 'No'})
# Port(start=475, end=475, category='WellKnown', description='tcpnethaspsrv, Aladdin Knowledge Systems Hasp services', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=476, end=490, category='WellKnown', description='Centro Software ERP ports', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=491, end=491, category='WellKnown', description='GO-Global remote access and application publishing software', types={'tcp': 'Unofficial'})
# Port(start=497, end=497, category='WellKnown', description='Retrospect', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=500, end=500, category='WellKnown', description='Internet Security Association and Key Management Protocol (ISAKMP) / Internet Key Exchange (IKE)', types={'tcp': 'Assigned', 'udp': 'Yes'})
# Port(start=502, end=502, category='WellKnown', description='Modbus Protocol', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=504, end=504, category='WellKnown', description='Citadel, multiservice protocol for dedicated clients for the Citadel groupware system', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=510, end=510, category='WellKnown', description='FirstClass Protocol (FCP), used by FirstClass client/server groupware system', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=512, end=512, category='WellKnown', description='Rexec, Remote Process Execution', types={'tcp': 'Yes'})
# Port(start=512, end=512, category='WellKnown', description='comsat, together with biff', types={'udp': 'Yes'})
# Port(start=513, end=513, category='WellKnown', description='rlogin', types={'tcp': 'Yes'})
# Port(start=513, end=513, category='WellKnown', description='Who', types={'udp': 'Yes'})
# Port(start=514, end=514, category='WellKnown', description='Remote Shell, used to execute non-interactive commands on a remote system (Remote Shell, rsh, remsh)', types={'tcp': 'Unofficial'})
# Port(start=514, end=514, category='WellKnown', description='Syslog, used for system logging', types={'tcp': 'No', 'udp': 'Yes'})
# Port(start=515, end=515, category='WellKnown', description='Line Printer Daemon (LPD), print service', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=517, end=517, category='WellKnown', description='Talk', types={'udp': 'Yes'})
# Port(start=518, end=518, category='WellKnown', description='NTalk', types={'udp': 'Yes'})
# Port(start=520, end=520, category='WellKnown', description='efs, extended file name server', types={'tcp': 'Yes'})
# Port(start=520, end=520, category='WellKnown', description='Routing Information Protocol (RIP)', types={'udp': 'Yes'})
# Port(start=521, end=521, category='WellKnown', description='Routing Information Protocol Next Generation (RIPng)', types={'udp': 'Yes'})
# Port(start=524, end=524, category='WellKnown', description='NetWare Core Protocol (NCP) is used for a variety things such as access to primary NetWare server resources, Time Synchronization, etc.', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=525, end=525, category='WellKnown', description='Timed, Timeserver', types={'udp': 'Yes'})
# Port(start=530, end=530, category='WellKnown', description='Remote procedure call (RPC)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=532, end=532, category='WellKnown', description='netnews', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=533, end=533, category='WellKnown', description='netwall, for emergency broadcasts', types={'udp': 'Yes'})
# Port(start=540, end=540, category='WellKnown', description='Unix-to-Unix Copy Protocol (UUCP)', types={'tcp': 'Yes'})
# Port(start=542, end=542, category='WellKnown', description='commerce (Commerce Applications)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=543, end=543, category='WellKnown', description='klogin, Kerberos login', types={'tcp': 'Yes'})
# Port(start=544, end=544, category='WellKnown', description='kshell, Kerberos Remote shell', types={'tcp': 'Yes'})
# Port(start=546, end=546, category='WellKnown', description='DHCPv6 client', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=547, end=547, category='WellKnown', description='DHCPv6 server', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=548, end=548, category='WellKnown', description='Apple Filing Protocol (AFP) over TCP', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=550, end=550, category='WellKnown', description='new-rwho, new-who', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=554, end=554, category='WellKnown', description='Real Time Streaming Protocol (RTSP)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=556, end=556, category='WellKnown', description='Remotefs, RFS, rfs_server', types={'tcp': 'Yes'})
# Port(start=560, end=560, category='WellKnown', description='rmonitor, Remote Monitor', types={'udp': 'Yes'})
# Port(start=561, end=561, category='WellKnown', description='monitor', types={'udp': 'Yes'})
# Port(start=563, end=563, category='WellKnown', description='NNTP over TLS/SSL (NNTPS)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=564, end=564, category='WellKnown', description='9P (Plan 9)', types={'tcp': 'Unofficial'})
# Port(start=585, end=585, category='WellKnown', description='Previously assigned for use of Internet Message Access Protocol over TLS/SSL (IMAPS), now deregistered in favour of port 993.', types={'tcp': 'No', 'udp': 'No'})
# Port(start=587, end=587, category='WellKnown', description='Email Message Submission (No longer preferred; see port 465.)', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=591, end=591, category='WellKnown', description='FileMaker 6.0 (and later) Web Sharing (HTTP Alternate, also see port 80)', types={'tcp': 'Yes'})
# Port(start=593, end=593, category='WellKnown', description='HTTP RPC Ep Map, Remote procedure call over Hypertext Transfer Protocol, often used by Distributed Component Object Model services and Microsoft Exchange Server', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=601, end=601, category='WellKnown', description='Reliable Syslog Service — used for system logging', types={'tcp': 'Yes'})
# Port(start=604, end=604, category='WellKnown', description='TUNNEL profile, a protocol for BEEP peers to form an application layer tunnel', types={'tcp': 'Yes'})
# Port(start=623, end=623, category='WellKnown', description='ASF Remote Management and Control Protocol (ASF-RMCP) & IPMI Remote Management Protocol', types={'udp': 'Yes'})
# Port(start=625, end=625, category='WellKnown', description='Open Directory Proxy (ODProxy)', types={'tcp': 'Unofficial', 'udp': 'No'})
# Port(start=631, end=631, category='WellKnown', description='Internet Printing Protocol (IPP)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=631, end=631, category='WellKnown', description='Common Unix Printing System (CUPS) administration console (extension to IPP)', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=635, end=635, category='WellKnown', description='RLZ DBase', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=636, end=636, category='WellKnown', description='Lightweight Directory Access Protocol over TLS/SSL (LDAPS)', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=639, end=639, category='WellKnown', description='Multicast Source Discovery Protocol, MSDP', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=641, end=641, category='WellKnown', description='SupportSoft Nexus Remote Command (control/listening), a proxy gateway connecting remote control traffic', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=643, end=643, category='WellKnown', description='SANity', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=646, end=646, category='WellKnown', description='Label Distribution Protocol (LDP), a routing protocol used in MPLS networks', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=647, end=647, category='WellKnown', description='DHCP Failover protocol', types={'tcp': 'Yes'})
# Port(start=648, end=648, category='WellKnown', description='Registry Registrar Protocol (RRP)', types={'tcp': 'Yes'})
# Port(start=651, end=651, category='WellKnown', description='IEEE-MMS', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=653, end=653, category='WellKnown', description='SupportSoft Nexus Remote Command (data), a proxy gateway connecting remote control traffic', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=654, end=654, category='WellKnown', description='Media Management System (MMS) Media Management Protocol (MMP)', types={'tcp': 'Yes'})
# Port(start=655, end=655, category='WellKnown', description='Tinc VPN daemon', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=657, end=657, category='WellKnown', description='IBM RMC (Remote monitoring and Control) protocol, used by System p5 AIX Integrated Virtualization Manager (IVM) and Hardware Management Console to connect managed logical partitions (LPAR) to enable dynamic partition reconfiguration', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=660, end=660, category='WellKnown', description='macOS Server administration, version 10.4 and earlier', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=662, end=662, category='WellKnown', description='NFS v3 Statd port', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=666, end=666, category='WellKnown', description='Doom, the first online first-person shooter', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=666, end=666, category='WellKnown', description="airserv-ng, aircrack-ng's server for remote-controlling wireless devices", types={'tcp': 'Unofficial'})
# Port(start=674, end=674, category='WellKnown', description='Application Configuration Access Protocol (ACAP)', types={'tcp': 'Yes'})
# Port(start=684, end=684, category='WellKnown', description='CORBA IIOP SSL', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=688, end=688, category='WellKnown', description='REALM-RUSD (ApplianceWare Server Appliance Management Protocol)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=690, end=690, category='WellKnown', description='Velneo Application Transfer Protocol (VATP)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=691, end=691, category='WellKnown', description='MS Exchange Routing', types={'tcp': 'Yes'})
# Port(start=694, end=694, category='WellKnown', description='Linux-HA high-availability heartbeat', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=695, end=695, category='WellKnown', description='IEEE Media Management System over SSL (IEEE-MMS-SSL)', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=698, end=698, category='WellKnown', description='Optimized Link State Routing (OLSR)', types={'udp': 'Yes'})
# Port(start=700, end=700, category='WellKnown', description='Extensible Provisioning Protocol (EPP), a protocol for communication between domain name registries and registrars (RFC 5734)', types={'tcp': 'Yes'})
# Port(start=701, end=701, category='WellKnown', description='Link Management Protocol (LMP), a protocol that runs between a pair of nodes and is used to manage traffic engineering (TE) links', types={'tcp': 'Yes'})
# Port(start=702, end=702, category='WellKnown', description='IRIS (Internet Registry Information Service) over BEEP (Blocks Extensible Exchange Protocol) (RFC 3983)', types={'tcp': 'Yes'})
# Port(start=706, end=706, category='WellKnown', description='Secure Internet Live Conferencing (SILC)', types={'tcp': 'Yes'})
# Port(start=711, end=711, category='WellKnown', description='Cisco Tag Distribution Protocol—being replaced by the MPLS Label Distribution Protocol', types={'tcp': 'Yes'})
# Port(start=712, end=712, category='WellKnown', description='Topology Broadcast based on Reverse-Path Forwarding routing protocol (TBRPF; RFC 3684)', types={'tcp': 'Yes'})
# Port(start=749, end=749, category='WellKnown', description='Kerberos administration', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=750, end=750, category='WellKnown', description='kerberos-iv, Kerberos version IV', types={'udp': 'Yes'})
# Port(start=751, end=751, category='WellKnown', description='kerberos_master, Kerberos authentication', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=752, end=752, category='WellKnown', description='passwd_server, Kerberos password (kpasswd) server', types={'udp': 'Unofficial'})
# Port(start=753, end=753, category='WellKnown', description='Reverse Routing Header (RRH)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=753, end=753, category='WellKnown', description='userreg_server, Kerberos userreg server', types={'udp': 'Unofficial'})
# Port(start=754, end=754, category='WellKnown', description='tell send', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=754, end=754, category='WellKnown', description='krb5_prop, Kerberos v5 slave propagation', types={'tcp': 'Unofficial'})
# Port(start=760, end=760, category='WellKnown', description='krbupdate [kreg], Kerberos registration', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=777, end=777, category='WellKnown', description='machine socket eXtension [msx] protocol', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=782, end=782, category='WellKnown', description='Conserver serial-console management server', types={'tcp': 'Unofficial'})
# Port(start=783, end=783, category='WellKnown', description='SpamAssassin spamd daemon', types={'tcp': 'Unofficial'})
# Port(start=800, end=800, category='WellKnown', description='mdbs-daemon', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=802, end=802, category='WellKnown', description='MODBUS/TCP Security', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=808, end=808, category='WellKnown', description='Microsoft Net.TCP Port Sharing Service', types={'tcp': 'Unofficial'})
# Port(start=829, end=829, category='WellKnown', description='Certificate Management Protocol', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=830, end=830, category='WellKnown', description='NETCONF over SSH', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=831, end=831, category='WellKnown', description='NETCONF over BEEP', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=832, end=832, category='WellKnown', description='NETCONF for SOAP over HTTPS', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=833, end=833, category='WellKnown', description='NETCONF for SOAP over BEEP', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=843, end=843, category='WellKnown', description='Adobe Flash', types={'tcp': 'Unofficial'})
# Port(start=847, end=847, category='WellKnown', description='DHCP Failover protocol', types={'tcp': 'Yes'})
# Port(start=848, end=848, category='WellKnown', description='Group Domain Of Interpretation (GDOI) protocol', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=853, end=853, category='WellKnown', description='DNS over TLS (RFC 7858)', types={'tcp': 'Yes'})
# Port(start=853, end=853, category='WellKnown', description='DNS over QUIC or DNS over DTLS', types={'udp': 'Yes'})
# Port(start=860, end=860, category='WellKnown', description='iSCSI (RFC 3720)', types={'tcp': 'Yes'})
# Port(start=861, end=861, category='WellKnown', description='OWAMP control (RFC 4656)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=862, end=862, category='WellKnown', description='TWAMP control (RFC 5357)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=873, end=873, category='WellKnown', description='rsync file synchronization protocol', types={'tcp': 'Yes'})
# Port(start=888, end=888, category='WellKnown', description='cddbp, CD DataBase (CDDB) protocol (CDDBP)', types={'tcp': 'Unofficial'})
# Port(start=888, end=888, category='WellKnown', description='IBM Endpoint Manager Remote Control', types={'tcp': 'Unofficial'})
# Port(start=892, end=892, category='WellKnown', description='NFS v3 Mountd port', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=897, end=897, category='WellKnown', description='Brocade SMI-S RPC', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=898, end=898, category='WellKnown', description='Brocade SMI-S RPC SSL', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=902, end=902, category='WellKnown', description='VMware ESXi', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=903, end=903, category='WellKnown', description='VMware ESXi', types={'tcp': 'Unofficial'})
# Port(start=953, end=953, category='WellKnown', description='BIND remote name daemon control (RNDC)', types={'tcp': 'Yes', 'udp': 'Reserved'})
# Port(start=981, end=981, category='WellKnown', description='Remote HTTPS management for firewall devices running embedded Check Point VPN-1 software', types={'tcp': 'Unofficial'})
# Port(start=987, end=987, category='WellKnown', description='Sony PlayStation Wake On Lan', types={'udp': 'Unofficial'})
# Port(start=987, end=987, category='WellKnown', description='Microsoft Remote Web Workplace, a feature of Windows Small Business Server', types={'tcp': 'Unofficial'})
# Port(start=988, end=988, category='WellKnown', description='Lustre (file system) Protocol (data).', types={'tcp': 'Unofficial'})
# Port(start=989, end=989, category='WellKnown', description='FTPS Protocol (data), FTP over TLS/SSL', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=990, end=990, category='WellKnown', description='FTPS Protocol (control), FTP over TLS/SSL', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=991, end=991, category='WellKnown', description='Netnews Administration System (NAS)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=992, end=992, category='WellKnown', description='Telnet protocol over TLS/SSL', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=993, end=993, category='WellKnown', description='Internet Message Access Protocol over TLS/SSL (IMAPS)', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=994, end=994, category='WellKnown', description='Previously assigned to Internet Relay Chat over TLS/SSL (IRCS), but was not used in common practice.', types={'tcp': 'Reserved', 'udp': 'Reserved'})
# Port(start=995, end=995, category='WellKnown', description='Post Office Protocol 3 over TLS/SSL (POP3S)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1010, end=1010, category='WellKnown', description='ThinLinc web-based administration interface', types={'tcp': 'Unofficial'})
# Port(start=1011, end=1020, category='WellKnown', description='', types={'tcp': 'Reserved', 'udp': 'Reserved'})
# Port(start=1023, end=1023, category='WellKnown', description='', types={'tcp': 'Reserved', 'udp': 'Reserved'})
# Port(start=1023, end=1023, category='WellKnown', description='z/OS Network File System (NFS) (potentially ports 991–1023)', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=1024, end=1024, category='Registered', description='Reserved', types={'tcp': 'Reserved', 'udp': 'Reserved'})
# Port(start=1025, end=1025, category='Registered', description='network blackjack', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=1027, end=1027, category='Registered', description='Reserved', types={'tcp': 'Reserved'})
# Port(start=1027, end=1027, category='Registered', description='Native IPv6 behind IPv4-to-IPv4 NAT Customer Premises Equipment (6a44)', types={'udp': 'Yes'})
# Port(start=1029, end=1029, category='Registered', description='Microsoft DCOM services', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=1058, end=1058, category='Registered', description='nim, IBM AIX Network Installation Manager (NIM)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1059, end=1059, category='Registered', description='nimreg, IBM AIX Network Installation Manager (NIM)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1080, end=1080, category='Registered', description='SOCKS proxy', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1085, end=1085, category='Registered', description='WebObjects', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1098, end=1098, category='Registered', description='rmiactivation, Java remote method invocation (RMI) activation', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1099, end=1099, category='Registered', description='rmiregistry, Java remote method invocation (RMI) registry', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=1100, end=1100, category='Registered', description='SaltoSystems - Handshake for IP-Components', types={'udp': 'Unofficial'})
# Port(start=1112, end=1112, category='Registered', description='ESET virus updates', types={'tcp': 'Unofficial'})
# Port(start=1113, end=1113, category='Registered', description='Licklider Transmission Protocol (LTP) delay tolerant networking protocol', types={'tcp': 'Assigned', 'udp': 'Yes'})
# Port(start=1119, end=1119, category='Registered', description="Battle.net chat/game protocol, used by Blizzard's games", types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1144, end=1144, category='Registered', description='fuscript (Fusion Script) used by Blackmagic Design Fusion and DaVinci Resolve', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1167, end=1167, category='Registered', description='Cisco IP SLA (Service Assurance Agent)', types={'tcp': 'Yes', 'udp': 'Yes', 'sctp': 'Yes'})
# Port(start=1194, end=1194, category='Registered', description='OpenVPN', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1198, end=1198, category='Registered', description='The cajo project Free dynamic transparent distributed computing in Java', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1212, end=1212, category='Registered', description='Equalsocial Fediverse protocol', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=1214, end=1214, category='Registered', description='Kazaa', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1220, end=1220, category='Registered', description='QuickTime Streaming Server administration', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=1234, end=1234, category='Registered', description='Infoseek search agent', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1234, end=1234, category='Registered', description='VLC media player default port for UDP/RTP stream', types={'udp': 'Unofficial'})
# Port(start=1241, end=1241, category='Registered', description='Nessus Security Scanner', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=1270, end=1270, category='Registered', description='Microsoft System Center Operations Manager (SCOM) (formerly Microsoft Operations Manager (MOM)) agent', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1293, end=1293, category='Registered', description='Internet Protocol Security (IPSec)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1311, end=1311, category='Registered', description='Windows RxMon.exe', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1311, end=1311, category='Registered', description='Dell OpenManage HTTPS', types={'tcp': 'Unofficial'})
# Port(start=1314, end=1314, category='Registered', description='Festival Speech Synthesis System server', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=1319, end=1319, category='Registered', description='AMX ICSP (Protocol for communications with AMX control systems devices)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1337, end=1337, category='Registered', description='Men&Mice DNS', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1337, end=1337, category='Registered', description='Strapi', types={'tcp': 'Unofficial'})
# Port(start=1337, end=1337, category='Registered', description='Razer Chroma SDK Server', types={'tcp': 'Unofficial'})
# Port(start=1337, end=1337, category='Registered', description='Sails.js default port', types={'tcp': 'Unofficial'})
# ...
# Port(start=1714, end=1764, category='Registered', description='KDE Connect', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=1716, end=1716, category='Registered', description="America's Army, a massively multiplayer online game (MMO)", types={'udp': 'Unofficial'})
# Port(start=1719, end=1719, category='Registered', description='H.323 registration and alternate communication', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1720, end=1720, category='Registered', description='H.323 call signaling', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1723, end=1723, category='Registered', description='Point-to-Point Tunneling Protocol (PPTP)', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=1755, end=1755, category='Registered', description='Microsoft Media Services (MMS, ms-streaming)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1761, end=1761, category='Registered', description='Novell ZENworks', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=1776, end=1776, category='Registered', description='Emergency management information system', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1801, end=1801, category='Registered', description='Microsoft Message Queuing', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1812, end=1812, category='Registered', description='RADIUS authentication protocol, radius', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1813, end=1813, category='Registered', description='RADIUS accounting protocol, radius-acct', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1863, end=1863, category='Registered', description='Microsoft Notification Protocol (MSNP), used by the Microsoft Messenger service and a number of instant messaging Messenger clients', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1880, end=1880, category='Registered', description='Node-RED', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=1883, end=1883, category='Registered', description='MQTT (formerly MQ Telemetry Transport)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1900, end=1900, category='Registered', description='Simple Service Discovery Protocol (SSDP), discovery of UPnP devices', types={'tcp': 'Assigned', 'udp': 'Yes'})
# Port(start=1935, end=1935, category='Registered', description="Macromedia Flash Communications Server MX, the precursor to Adobe Flash Media Server before Macromedia's acquisition by Adobe on December 3, 2005", types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1935, end=1935, category='Registered', description='Real Time Messaging Protocol (RTMP)', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=1965, end=1965, category='Registered', description='Gemini, a lightweight, collaboratively designed protocol, striving to fill the gap between Gopher and HTTP', types={'tcp': 'Unofficial', 'udp': 'No'})
# Port(start=1967, end=1967, category='Registered', description='Cisco IOS IP Service Level Agreements (IP SLAs) Control Protocol[citation needed]', types={'udp': 'Unofficial'})
# Port(start=1972, end=1972, category='Registered', description='InterSystems Caché, and InterSystems IRIS versions 2020.3 and later', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1984, end=1984, category='Registered', description='Big Brother', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1984, end=1984, category='Registered', description='Arweave mining node', types={'tcp': 'Unofficial'})
# Port(start=1985, end=1985, category='Registered', description='Cisco Hot Standby Router Protocol (HSRP)[self-published source]', types={'tcp': 'Assigned', 'udp': 'Yes'})
# Port(start=1998, end=1998, category='Registered', description='Cisco X.25 over TCP (XOT) service', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2000, end=2000, category='Registered', description='Cisco Skinny Client Control Protocol (SCCP)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2001, end=2009, category='Registered', description='hexss http server (python package)', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=2010, end=2010, category='Registered', description='Artemis: Spaceship Bridge Simulator', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=2019, end=2019, category='Registered', description='Caddy admin API endpoint', types={'tcp': 'Unofficial'})
# Port(start=2033, end=2033, category='Registered', description='Civilization IV multiplayer', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=2049, end=2049, category='Registered', description='Network File System (NFS)', types={'tcp': 'Yes', 'udp': 'Yes', 'sctp': 'Yes'})
# Port(start=2056, end=2056, category='Registered', description='Civilization IV multiplayer', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=2080, end=2080, category='Registered', description='Autodesk NLM (FLEXlm)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2082, end=2082, category='Registered', description='cPanel default', types={'tcp': 'Unofficial'})
# Port(start=2083, end=2083, category='Registered', description='Secure RADIUS Service (radsec)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2083, end=2083, category='Registered', description='cPanel default TLS', types={'tcp': 'Unofficial'})
# Port(start=2086, end=2086, category='Registered', description='GNUnet', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2086, end=2086, category='Registered', description='WebHost Manager default', types={'tcp': 'Unofficial'})
# Port(start=2087, end=2087, category='Registered', description='WebHost Manager default TLS', types={'tcp': 'Unofficial'})
# Port(start=2095, end=2095, category='Registered', description='cPanel default web mail', types={'tcp': 'Yes'})
# Port(start=2096, end=2096, category='Registered', description='cPanel default TLS web mail', types={'tcp': 'Unofficial'})
# Port(start=2100, end=2100, category='Registered', description='Warzone 2100 multiplayer[citation needed]', types={'tcp': 'Unofficial'})
# Port(start=2101, end=2101, category='Registered', description='Networked Transport of RTCM via Internet Protocol (NTRIP)[citation needed]', types={'tcp': 'Unofficial'})
# Port(start=2102, end=2102, category='Registered', description='Zephyr Notification Service server', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2103, end=2103, category='Registered', description='Zephyr Notification Service serv-hm connection', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2104, end=2104, category='Registered', description='Zephyr Notification Service hostmanager', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2123, end=2123, category='Registered', description='GTP control messages (GTP-C)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2137, end=2137, category='Registered', description='', types={'tcp': 'Unofficial', 'udp': 'Unofficial', 'sctp': 'Unofficial', 'dccp': 'Unofficial'})
# Port(start=2142, end=2142, category='Registered', description='TDMoIP (TDM over IP)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2152, end=2152, category='Registered', description='GTP user data messages (GTP-U)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2159, end=2159, category='Registered', description='GDB remote debug port', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2181, end=2181, category='Registered', description='EForward-document transport system', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2181, end=2181, category='Registered', description='Apache ZooKeeper default client port[citation needed]', types={'tcp': 'Unofficial'})
# Port(start=2195, end=2195, category='Registered', description='Apple Push Notification Service, binary, gateway.  Deprecated March 2021.', types={'tcp': 'Unofficial'})
# Port(start=2196, end=2196, category='Registered', description='Apple Push Notification Service, binary, feedback.  Deprecated March 2021.', types={'tcp': 'Unofficial'})
# Port(start=2197, end=2197, category='Registered', description='Apple Push Notification Service, HTTP/2, JSON-based API.', types={'tcp': 'Unofficial'})
# Port(start=2210, end=2210, category='Registered', description='NOAAPORT Broadcast Network', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2211, end=2211, category='Registered', description='EMWIN', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2221, end=2221, category='Registered', description='ESET anti-virus updates', types={'tcp': 'Unofficial'})
# Port(start=2222, end=2222, category='Registered', description='EtherNet/IP implicit messaging for IO data', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2222, end=2222, category='Registered', description='DirectAdmin Access', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=2222, end=2226, category='Registered', description='ESET Remote administrator', types={'tcp': 'Yes'})
# Port(start=2240, end=2240, category='Registered', description='General Dynamics Remote Encryptor Configuration Information Protocol (RECIPe)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2261, end=2261, category='Registered', description='CoMotion master', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2262, end=2262, category='Registered', description='CoMotion backup', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2302, end=2302, category='Registered', description='ArmA multiplayer', types={'udp': 'Unofficial'})
# Port(start=2302, end=2302, category='Registered', description='Halo: Combat Evolved multiplayer host', types={'udp': 'Unofficial'})
# Port(start=2303, end=2303, category='Registered', description='ArmA multiplayer (default port for game +1)', types={'udp': 'Unofficial'})
# Port(start=2303, end=2303, category='Registered', description='Halo: Combat Evolved multiplayer listener', types={'udp': 'Unofficial'})
# Port(start=2305, end=2305, category='Registered', description='ArmA multiplayer (default port for game +3)', types={'udp': 'Unofficial'})
# Port(start=2351, end=2351, category='Registered', description='AIM game LAN network port[citation needed]', types={'tcp': 'Unofficial'})
# Port(start=2368, end=2368, category='Registered', description='Ghost (blogging platform)', types={'tcp': 'Unofficial'})
# Port(start=2369, end=2369, category='Registered', description='Default for BMC Control-M/Server Configuration Agent', types={'tcp': 'Unofficial'})
# Port(start=2370, end=2370, category='Registered', description='Default for BMC Control-M/Server, to allow the Control-M/Enterprise Manager to connect to the Control-M/Server', types={'tcp': 'Unofficial'})
# Port(start=2372, end=2372, category='Registered', description='Default for K9 Web Protection/parental controls, content filtering agent[citation needed]', types={'tcp': 'Unofficial'})
# Port(start=2375, end=2375, category='Registered', description='Docker REST API (plain)', types={'tcp': 'Yes', 'udp': 'Reserved'})
# Port(start=2376, end=2376, category='Registered', description='Docker REST API (SSL)', types={'tcp': 'Yes', 'udp': 'Reserved'})
# Port(start=2377, end=2377, category='Registered', description='Docker Swarm cluster management communications[self-published source]', types={'tcp': 'Yes', 'udp': 'Reserved'})
# Port(start=2379, end=2379, category='Registered', description='CoreOS etcd client communication', types={'tcp': 'Yes', 'udp': 'Reserved'})
# Port(start=2379, end=2379, category='Registered', description='KGS Go Server', types={'tcp': 'Unofficial'})
# Port(start=2380, end=2380, category='Registered', description='CoreOS etcd server communication', types={'tcp': 'Yes', 'udp': 'Reserved'})
# Port(start=2389, end=2389, category='Registered', description='OpenView Session Mgr', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=2399, end=2399, category='Registered', description='FileMaker Data Access Layer (ODBC/JDBC)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2401, end=2401, category='Registered', description='CVS version control system password-based server', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2404, end=2404, category='Registered', description='IEC 60870-5-104, used to send electric power telecontrol messages between two systems via directly connected data circuits', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2424, end=2424, category='Registered', description='OrientDB database listening for binary client connections', types={'tcp': 'Unofficial'})
# Port(start=2426, end=2426, category='Registered', description='VMware VeloCloud Multipath Protocol (VCMP) Dynamic Multipath Optimization (DMPO)', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=2427, end=2427, category='Registered', description='Media Gateway Control Protocol (MGCP) media gateway', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2447, end=2447, category='Registered', description='ovwdb—OpenView Network Node Manager (NNM) daemon', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2456, end=2456, category='Registered', description='Valheim', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=2459, end=2459, category='Registered', description='XRPL', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2480, end=2480, category='Registered', description='OrientDB database listening for HTTP client connections', types={'tcp': 'Unofficial'})
# Port(start=2483, end=2483, category='Registered', description='Oracle database listening for insecure client connections, replaces port 1521[when?]', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2484, end=2484, category='Registered', description='Oracle database listening for SSL client connections', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2500, end=2500, category='Registered', description='NetFS communication', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=2501, end=2501, category='Registered', description='NetFS probe', types={'udp': 'Unofficial'})
# Port(start=2535, end=2535, category='Registered', description='Multicast Address Dynamic Client Allocation Protocol (MADCAP). All standard messages are UDP datagrams.', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2541, end=2541, category='Registered', description='LonTalk/IP', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2546, end=2548, category='Registered', description='EVault data protection services', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2593, end=2593, category='Registered', description='Ultima Online servers[citation needed]', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=2598, end=2598, category='Registered', description='Citrix Independent Computing Architecture (ICA) with Session Reliability; port 1494 without session reliability', types={'tcp': 'Unofficial'})
# Port(start=2599, end=2599, category='Registered', description='Ultima Online servers[citation needed]', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=2628, end=2628, category='Registered', description='DICT', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2638, end=2638, category='Registered', description='SQL Anywhere database server', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2710, end=2710, category='Registered', description='XBT Tracker. UDP tracker extension is considered experimental.', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=2727, end=2727, category='Registered', description='Media Gateway Control Protocol (MGCP) media gateway controller (call agent)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2759, end=2759, category='Registered', description='SuperTuxKart server', types={'udp': 'Unofficial'})
# Port(start=2761, end=2761, category='Registered', description='DICOM over Integrated Secure Communication Layer (ISCL)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2762, end=2762, category='Registered', description='DICOM over TLS', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2775, end=2775, category='Registered', description='Short Message Peer-to-Peer (SMPP)[citation needed]', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2809, end=2809, category='Registered', description='corbaloc:iiop URL, per the CORBA 3.0.3 specification', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2811, end=2811, category='Registered', description='gsi ftp, per the GridFTP specification', types={'tcp': 'Yes', 'udp': 'Yes'})

# %%
with open("ports.json", "w") as f:
    json.dump([asdict(port) for port in ports], f)
